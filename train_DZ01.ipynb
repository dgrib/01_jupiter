# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
train_df = pd.read_csv('train.csv')
train_df.tail()  # Проверка корректности импорта.
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 9995   1260          61    2.0  49.090728   33.272626            6.0      3
# 9996  16265          27    2.0  64.307684   37.038420            9.0     13
# 9997   2795         178    1.0  29.648057   16.555363            5.0      3
# 9998  14561          21    1.0  32.330292   22.326870            5.0      3
# 9999   7202          94    1.0  35.815476   22.301367            6.0      9
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 9995        12.0       1981   0.300323         B         B        52
# 9996         0.0       1977   0.072158         B         B         2
# 9997         5.0       1958   0.460556         B         B        20
# 9998         9.0       1969   0.194489         B         B        47
# 9999         9.0       1975   0.127376         B         B        43
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# ...

# %%
train_df.dtypes
# Out:
# Id                 int64
# DistrictId         int64
# Rooms            float64
# Square           float64
# LifeSquare       float64
# KitchenSquare    float64
# Floor              int64
# HouseFloor       float64
# HouseYear          int64
# Ecology_1        float64
# Ecology_2         object
# Ecology_3         object
# Social_1           int64
# Social_2           int64
# Social_3           int64
# Healthcare_1     float64
# Helthcare_2        int64
# Shops_1            int64
# Shops_2           object
# Price            float64
# dtype: object

# %% [markdown]
# ## Задание 1.
# Посчитать основные статистики по каждому признаку (минимальные, максимальные, средние значения). Сделать выводы об адекватности этих статистик.

# %%
train_df.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# ...

# %%
train_df.describe().loc[['min', 'max', 'mean'], :]
# Out:
#               Id  DistrictId    Rooms      Square   LifeSquare  KitchenSquare  \
# min       0.0000      0.0000   0.0000    1.136859     0.370619         0.0000
# max   16798.0000    209.0000  19.0000  641.065193  7480.592129      2014.0000
# mean   8383.4077     50.4008   1.8905   56.315775    37.199645         6.2733
#
#         Floor  HouseFloor     HouseYear  Ecology_1  Social_1    Social_2  \
# min    1.0000      0.0000  1.910000e+03   0.000000     0.000    168.0000
# max   42.0000    117.0000  2.005201e+07   0.521867    74.000  19083.0000
# mean   8.5267     12.6094  3.990166e+03   0.118858    24.687   5352.1574
#
#       Social_3  Healthcare_1  Helthcare_2  Shops_1          Price
# min     0.0000       0.00000       0.0000   0.0000   59174.778028
# max   141.0000    4849.00000       6.0000  23.0000  633233.466570
# mean    8.0392    1142.90446       1.3195   4.2313  214138.857399

# %% [raw]
# Адекватные:
#     Floor,
#     Price,
# Сомнительные:
#     Rooms (смущает min = 0),
#     Square (min = 1.1),
#     LifeSquare (min = 0.37),
#     KitchenSquare (max = 2014),
# Неадекватные:
#     HouseFloor (min = 0 этажность дома),
#     HouseYear (mean = 3990),
# Сложно делать выводы:
#     Экология, социалка, здоровье, магазины - относительные показатели.

# %% [markdown]
# ## Задание 2.
# Посчитать для каждого признака, сколько в нем уникальных значений и как часто они встречаются. Сделать выводы по каждому признаку.

# %% [markdown]
# 1. Rooms

# %%
train_df[['Rooms']].value_counts()
# Out:
# Rooms
# 2.0      3880
# 1.0      3705
# 3.0      2235
# 4.0       150
# 5.0        18
# 0.0         8
# 10.0        2
# 19.0        1
# 6.0         1
# dtype: int64

# %% [markdown]
# Надо будет посмотреть данные для 0 и более 5 комнат
#
# .

# %% [markdown]
# 2. Square

# %%
train_df[['Square']].value_counts()
# Out:
# Square
# 641.065193    1
# 44.265162     1
# 44.316346     1
# 44.308079     1
# 44.302140     1
#              ..
# 61.691076     1
# 61.690768     1
# 61.673568     1
# 61.672748     1
# 1.136859      1
# Length: 10000, dtype: int64

# %% [markdown]
# Посмотреть большие площади, max сильно отличается от mean
#
# .

# %% [markdown]
# 3. LifeSquare

# %%
train_df[['LifeSquare']].value_counts()
# Out:
# LifeSquare
# 7480.592129    1
# 26.894465      1
# 26.914978      1
# 26.915615      1
# 26.925315      1
#               ..
# 40.548087      1
# 40.551421      1
# 40.551864      1
# 40.559784      1
# 0.370619       1
# Length: 7887, dtype: int64

# %% [markdown]
# Посмотреть большие жилые площади, max сильно отличается от mean
#
# .

# %% [markdown]
# 4. KitchenSquare

# %%
train_df[['KitchenSquare']].value_counts()
# Out:
# KitchenSquare
# 1.0              2460
# 8.0              1306
# 5.0              1169
# 10.0             1075
# 6.0              1038
# 9.0               843
# 0.0               697
# 7.0               609
# 12.0              249
# 11.0              233
# 13.0               67
# 14.0               51
# 4.0                39
# 15.0               31
# 3.0                22
# 16.0               16
# 20.0               14
# 17.0               12
# 19.0               11
# 18.0                6
# 2.0                 4
# 22.0                3
# 32.0                2
# 25.0                2
# 30.0                2
# 51.0                2
# 112.0               2
# 43.0                2
# 41.0                2
# 58.0                2
# 37.0                2
# 96.0                1
# 84.0                1
# 78.0                1
# 75.0                1
# 54.0                1
# 72.0                1
# 66.0                1
# 123.0               1
# 63.0                1
# 62.0                1
# ...

# %% [markdown]
# Обратить внимание на площади кухни больше 100
#
# .

# %% [markdown]
# 5. Floor

# %%
train_df[['Floor']].value_counts()
# Out:
# Floor
# 4        949
# 5        876
# 3        872
# 6        802
# 7        759
# 8        643
# 9        604
# 2        588
# 10       553
# 11       457
# 12       438
# 13       398
# 14       362
# 16       290
# 15       287
# 17       256
# 1        235
# 18       185
# 19       121
# 20        68
# 21        59
# 22        54
# 24        53
# 25        34
# 23        25
# 26        18
# 27         5
# 28         3
# 32         2
# 37         1
# 31         1
# 33         1
# 42         1
# dtype: int64

# %% [markdown]
# С этажами все в порядке
#
# .

# %% [markdown]
# 6. HouseFloor

# %%
train_df[['HouseFloor']].value_counts()
# Out:
# HouseFloor
# 17.0          2331
# 9.0           1389
# 12.0          1074
# 5.0           1031
# 14.0           625
# 16.0           576
# 1.0            497
# 25.0           374
# 22.0           343
# 0.0            269
# 24.0           176
# 8.0            141
# 10.0           135
# 4.0            134
# 3.0            127
# 15.0           123
# 19.0           108
# 20.0           105
# 18.0            89
# 7.0             59
# 6.0             58
# 2.0             48
# 23.0            40
# 21.0            33
# 11.0            28
# 13.0            27
# 30.0            21
# 40.0             7
# 27.0             6
# 32.0             4
# 37.0             4
# 28.0             3
# 99.0             2
# 48.0             2
# 39.0             2
# 47.0             1
# 45.0             1
# 44.0             1
# 36.0             1
# 38.0             1
# 26.0             1
# 31.0             1
# 29.0             1
# 117.0            1
# dtype: int64

# %% [markdown]
# Этажность. Много 0, и 117, 99 под вопросом
#
# .

# %% [markdown]
# 7. HouseYear

# %%
train_df[['HouseYear']].value_counts()
# Out:
# HouseYear
# 1977         2652
# 2017          308
# 2016          305
# 2015          299
# 2014          210
#              ...
# 20052011        1
# 1928            1
# 1947            1
# 4968            1
# 1910            1
# Length: 97, dtype: int64

# %% [markdown]
# Обратить внимание на год, если количество менее 3.
#
# .

# %% [markdown]
# 8. Ecology_1

# %%
train_df[['Ecology_1']].value_counts()
# Out:
# Ecology_1
# 0.007122     587
# 0.000000     537
# 0.243205     511
# 0.072158     486
# 0.075779     346
#             ...
# 0.386772       6
# 0.011320       3
# 0.394094       2
# 0.012522       1
# 0.014334       1
# Length: 129, dtype: int64

# %% [markdown]
# Экология. Много 0
#
# .

# %% [markdown]
# 9. Social_1

# %%
train_df[['Social_1']].value_counts()
# Out:
# Social_1
# 2           688
# 1           654
# 25          557
# 5           528
# 30          465
# 23          434
# 6           377
# 22          367
# 53          355
# 34          311
# 33          252
# 46          245
# 31          243
# 43          238
# 9           213
# 36          209
# 21          207
# 37          205
# 24          205
# 0           201
# 52          201
# 35          200
# 47          177
# 74          176
# 39          159
# 27          151
# 28          144
# 4           141
# 11          138
# 42          129
# 26          127
# 16          123
# 19          118
# 66           99
# 17           96
# 49           95
# 18           92
# 32           87
# 41           83
# 50           79
# 29           70
# 38           64
# 8            62
# 15           51
# 20           50
# 14           46
# 10           24
# 13           22
# 12           18
# 7            15
# 3             9
# dtype: int64

# %% [markdown]
# Social_1 похоже все в порядке
#
# .

# %% [markdown]
# 10. Social_2

# %%
train_df[['Social_2']].value_counts()
# Out:
# Social_2
# 264         587
# 1564        511
# 629         486
# 1437        346
# 6398        245
#            ...
# 568           3
# 1423          3
# 662           2
# 528           1
# 507           1
# Length: 142, dtype: int64

# %% [markdown]
# Social_2 Посмотреть сколько значений больше 10000
#
# max сильно выше mean
#
# .

# %% [markdown]
# 11. Social_3

# %%
train_df[['Social_3']].value_counts()
# Out:
# Social_3
# 0           2997
# 1           1861
# 3           1136
# 4            835
# 2            635
# 6            423
# 5            391
# 141          245
# 9            192
# 7            184
# 11           172
# 8            170
# 10           142
# 16           101
# 14            97
# 27            59
# 48            58
# 56            49
# 84            43
# 24            37
# 87            27
# 59            25
# 93            25
# 19            22
# 20            19
# 23            18
# 39            15
# 73            10
# 45             9
# 37             3
# dtype: int64

# %% [markdown]
# Social_3 Похоже все норм
#
# .

# %% [markdown]
# 12. Healthcare_1

# %%
train_df[['Healthcare_1']].value_counts()
# Out:
# Healthcare_1
# 540.0           511
# 30.0            348
# 1046.0          245
# 750.0           163
# 229.0           148
#                ...
# 370.0            14
# 32.0             12
# 1815.0           10
# 35.0              2
# 0.0               1
# Length: 79, dtype: int64

# %% [markdown]
# Healthcare_1 всего 1 ноль и много незаполненных значений
#
# .

# %%
train_df[['Helthcare_2']].value_counts()
# Out:
# Helthcare_2
# 0              4214
# 1              2183
# 3              1670
# 2              1158
# 5               388
# 4               288
# 6                99
# dtype: int64

# %% [markdown]
# Helthcare_2 все хорошо
#
# .

# %%
train_df[['Shops_1']].value_counts()
# Out:
# Shops_1
# 0          2316
# 1          1325
# 5          1324
# 2           964
# 4           841
# 3           711
# 6           487
# 11          401
# 9           316
# 7           294
# 8           253
# 23          245
# 10          215
# 15          176
# 16           83
# 19           49
# dtype: int64

# %% [markdown]
# Shops_1 все хорошо
#
# .

# %% [markdown]
# ## Задание 3
# Используя выводы из двух предыдущих заданий, найдите те наблюдения, где есть пропуски, выбросы (неадекватные значения признака, которые отличаются от большинства), используя фильтрацию из pandas.

# %% [markdown]
# 1. Надо будет посмотреть данные для 0 и более 5 комнат

# %%
train_df.loc[(train_df['Rooms'] > 5)]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 2004   5927          57   10.0  59.056975   36.223072           10.0     22
# 2728  14865           9   10.0  60.871266   38.420681           10.0      3
# 6088   8491           1   19.0  42.006046   21.779288            7.0     17
# 8794  14003          99    6.0  59.414334   38.702244            6.0      7
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 2004        22.0       2002   0.090799         B         B        74
# 2728         2.0       1994   0.161532         B         B        25
# 6088        17.0       2014   0.007122         B         B         1
# 8794         9.0       1969   0.033494         B         B        66
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 2004     19083         2           NaN            5       15       B
# 2728      5648         1          30.0            2        4       B
# ...

# %% [markdown]
# это ошибки, 1 или 2 комнатные квартиры
#
# .

# %% [markdown]
# 2. Посмотреть большие площади, max сильно отличается от mean
#
# .

# %%
train_df.loc[(train_df['Square'] > 200)]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 726      28           9    2.0  604.705972         NaN            1.0     17
# 1776  16568          27    4.0  200.334539  201.627361           25.0      1
# 1906   5548          86    5.0  275.645284  233.949309           26.0     12
# 7010   2307         102    1.0  409.425181  410.639749           10.0      4
# 7644   7917          27    0.0  212.932361  211.231125            0.0      2
# 9229  11602          30    2.0  641.065193  638.163193           10.0     20
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 726         18.0       1977   0.161532         B         B        25
# 1776         2.0       2013   0.041116         B         B        53
# 1906        37.0       2011   0.161976         B         A        31
# 7010         4.0       2016   0.238617         B         B        26
# 7644         3.0       2008   0.211401         B         B         9
# ...

# %% [markdown]
# из выборки адекватное значение только 1906, у остальных нестыковка между Square и LifeSquare
#
# .

# %% [markdown]
# 3. Посмотреть большие жилые площади, max сильно отличается от mean

# %%
train_df.loc[(train_df['LifeSquare'] > 200)]
# Out:
#          Id  DistrictId  Rooms      Square   LifeSquare  KitchenSquare  Floor  \
# 357   14990          23    2.0   48.449873   263.542020            5.0      6
# 1776  16568          27    4.0  200.334539   201.627361           25.0      1
# 1906   5548          86    5.0  275.645284   233.949309           26.0     12
# 5183  15886          85    3.0   78.059331   461.463614           10.0     12
# 7010   2307         102    1.0  409.425181   410.639749           10.0      4
# 7644   7917          27    0.0  212.932361   211.231125            0.0      2
# 8000  16550          27    3.0   81.694417  7480.592129            1.0      9
# 9229  11602          30    2.0  641.065193   638.163193           10.0     20
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 357          5.0       1972   0.075779         B         B         6
# 1776         2.0       2013   0.041116         B         B        53
# ...

# %% [markdown]
# неадекват (и скорее всего запятую перенести влево на 1 знак) 357, 5183.
#
# в остальных случаях LifeSquare больше Square
#
# .

# %% [markdown]
# 3.1 Посмотреть где LifeSquare больше Square

# %%
train_df.loc[(train_df['Square'] < train_df['LifeSquare'])]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 33      847          74    2.0  73.314975   74.131261            1.0      7
# 64     3992           1    3.0  87.200625   87.730225            0.0     21
# 77    11771          45    1.0  38.467276   39.624493            1.0     11
# 100   13343          74    2.0  79.937665   82.931595            1.0      8
# 111   13875          20    1.0  28.438794   32.514021            6.0      6
# ...     ...         ...    ...        ...         ...            ...    ...
# 9960  16258          48    3.0  96.056784   98.152802            1.0     15
# 9962  14175          14    1.0  42.029175   44.682167           10.0      4
# 9979   2201           6    1.0  40.043234   41.984322            1.0      3
# 9987  11665           1    2.0  62.690057   64.602939           10.0     19
# 9993   9289           1    3.0  84.486078   88.931509            0.0      4
#
# ...

# %% [markdown]
# Это какая-то жесть (482 ячейки)
#
# .

# %% [markdown]
# 3.2 Посмотреть если LIfeSquare равно нулю

# %%
train_df.loc[(train_df['LifeSquare'].isnull())]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0     11809          27    3.0  115.027311         NaN           10.0      4
# 3      2352           1    1.0   40.409907         NaN            1.0     10
# 18     4581           1    1.0   47.582480         NaN            1.0     16
# 20     8768          63    1.0   50.974891         NaN            1.0      7
# 24     4717          27    1.0   44.203947         NaN            0.0      2
# ...     ...         ...    ...         ...         ...            ...    ...
# 9975   4944           6    2.0   52.573133         NaN            1.0     18
# 9978   4851           1    1.0   39.314342         NaN            1.0     13
# 9981   6753          62    2.0   73.092686         NaN            1.0      4
# 9983    647           1    2.0   63.324025         NaN            1.0      4
# 9991  11173           6    2.0   62.648779         NaN            0.0      6
#
# ...

# %% [markdown]
# Очень много значений с LifeSquare равно NaN
#
# .

# %% [markdown]
# 4. Обратить внимание на площади кухни больше 100

# %%
train_df.loc[(train_df['KitchenSquare'] > 100)]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 286    2737          27    3.0  123.430072  125.806981          123.0      5
# 5002   7441          62    3.0  114.734473  112.589083          112.0      3
# 6505  14679          81    1.0   32.276663   19.278394         1970.0      6
# 7733  12552          58    3.0  116.405693  113.109653          112.0      3
# 9520  14656          62    1.0   47.100719   46.447960         2014.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 286         10.0       2015   0.017647         B         B         2
# 5002         3.0       2015   0.072158         B         B         2
# 6505         1.0       1977   0.006076         B         B        30
# 7733         3.0       2016   0.437885         B         B        23
# 9520         1.0       2014   0.072158         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# ...

# %% [markdown]
# Все 5 ячеек неадекватные относительно площади кухни и остальных площадей
#
# .

# %% [markdown]
# 5. С этажами было все хорошо, нужно посмотреть есть где этаж больще этажности дома

# %% [markdown]
# 5.1 посмотреть есть где этаж больше этажности дома

# %%
train_df.query('(HouseFloor < Floor)')
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 17     1190           8    2.0  49.396000   28.299600            5.0      6
# 19      367          45    1.0  42.367289   40.012529            1.0     16
# 21     8471          20    3.0  75.611065   47.494621            8.0     11
# 24     4717          27    1.0  44.203947         NaN            0.0      2
# 25     4521           6    2.0  65.409965         NaN            1.0     18
# ...     ...         ...    ...        ...         ...            ...    ...
# 9960  16258          48    3.0  96.056784   98.152802            1.0     15
# 9968   9920           1    3.0  86.487550         NaN            1.0     18
# 9970  13501           6    1.0  41.310416   19.117077            9.0     18
# 9975   4944           6    2.0  52.573133         NaN            1.0     18
# 9996  16265          27    2.0  64.307684   37.038420            9.0     13
#
# ...

# %% [markdown]
# Очень много некорректных значений (этаж больще этажности дома), нужно разбираться подробнее потом
#
# .

# %% [markdown]
# 6. Этажность. Много 0, и 117, 99 под вопросом

# %%
train_df.query('(HouseFloor > 98)')
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 746    9300          74    2.0  71.747869   74.579809            9.0      5
# 1678     78          30    2.0  65.773749   66.811789            1.0      8
# 4657  10806           5    1.0  51.944587   48.709601            1.0      6
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 746         99.0       1977   0.075779         B         B         6
# 1678       117.0       1977   0.000078         B         B        22
# 4657        99.0       1977   0.150818         B         B        16
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 746       1437         3           NaN            0        2       B
# 1678      6398       141        1046.0            3       23       B
# 4657      3433         4        2643.0            4        5       B
#
#               Price
# 746   243329.912579
# 1678  207248.370520
# 4657  296127.115515

# %% [markdown]
# Скорее всего это опечатки, лишняя цифра
#
# .

# %% [markdown]
# 6.1 Смотрим HouseFloor = 0

# %%
train_df.query('(HouseFloor == 0)')
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 24     4717          27    1.0  44.203947         NaN            0.0      2
# 152   12947          53    2.0  56.023342         NaN            0.0     14
# 159   13146          74    1.0  46.449711         NaN            0.0      6
# 186   12174          62    1.0  44.954880         NaN            0.0      8
# 229   15661          45    3.0  81.094922         NaN            0.0     15
# ...     ...         ...    ...        ...         ...            ...    ...
# 9889    629          27    1.0  42.936724         NaN            0.0      2
# 9931  15686           1    1.0  47.402412         NaN            0.0     14
# 9940   4711           6    1.0  41.224118         NaN            0.0      8
# 9950   5383          48    3.0  98.994909         NaN            0.0      3
# 9996  16265          27    2.0  64.307684    37.03842            9.0     13
#
# ...

# %% [markdown]
# 269 ячеек с этажностью дома равной 0 (они также входят в 1825 ячеек где этажность дома меньше этажа)
#
# .

# %% [markdown]
# 7. Обратить внимание на год, если количество менее 3.

# %%
train_df[["HouseYear"]].value_counts()[train_df[["HouseYear"]].value_counts() < 3]
# Out:
# HouseYear
# 1941         2
# 1948         2
# 1932         2
# 1929         2
# 1912         2
# 1914         1
# 1916         1
# 20052011     1
# 1928         1
# 1947         1
# 4968         1
# 1910         1
# dtype: int64

# %% [markdown]
# Неадекатные значения 4968 и 20052011

# %% [markdown]
# 7.1 Проверить года более 2018 и менее 1900

# %%
train_df.query('HouseYear > 2020 | HouseYear < 1913')
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 2066  14556         183    4.0  151.150660   98.187482           23.0      6
# 2795   2085         161    1.0   63.293079   29.389815           18.0      3
# 6794  13288         161    1.0   50.808925   15.920343           20.0      8
# 8828  11607         147    2.0   44.791836   28.360393            5.0      4
# 9163  10814         109    1.0   37.265070   20.239714            9.0      9
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 2066         7.0       1912   0.037316         B         B        32
# 2795         9.0       1912   0.014423         B         B        19
# 6794         9.0       1910   0.014423         B         B        19
# 8828         9.0       4968   0.319809         B         B        25
# 9163        12.0   20052011   0.136330         B         B        30
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# ...

# %% [markdown]
# Так же как и в пункте 7. Неадекатные значения 4968 и 20052011
#
# .

# %% [markdown]
# 8. Экология. Много 0

# %% [markdown]
# Сложно оценивать без графиков. Оценивать по квартилям нет навыка.

# %% [markdown]
# 9. Social_1 Все хорошо

# %% [markdown]
# 10. Social_2 Посмотреть сколько значений больше 10000
#
# max сильно выше mean

# %%
train_df.query('(Social_2 > 14000)')
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 15     4328          96    1.0  36.673407   16.285522            9.0      3
# 145    8423          96    1.0  41.888845   22.447228            8.0     10
# 210    2510          27    1.0  38.737931   24.178119            8.0     14
# 211    8192          27    3.0  84.274055   50.505379            8.0      7
# 238     557          12    2.0  57.154361   35.821952            9.0      9
# ...     ...         ...    ...        ...         ...            ...    ...
# 9891   6001          96    4.0  99.263427   63.582708            9.0     11
# 9893  10736          13    3.0  80.030330   47.801599           10.0     16
# 9941  16031          96    1.0  35.474685   18.023801            9.0      6
# 9964  12763          27    1.0  43.963812   24.734367            8.0      2
# 9984  12566          13    1.0  40.234940   20.648798            7.0     10
#
# ...

# %% [markdown]
# Нет значений между 14000 и 19000 (которых 176 штук), это влияет на (max сильно выше mean)
#
# Непонимаю что с этим делать
#
# .

# %% [markdown]
# 11. Social_3 Все нормально

# %% [markdown]
# 12. Healthcare_1 всего 1 ноль и много незаполненных значений

# %%
train_df.loc[(train_df['Healthcare_1'].isnull())]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0     11809          27    3.0  115.027311         NaN           10.0      4
# 3      2352           1    1.0   40.409907         NaN            1.0     10
# 4     13866          94    2.0   64.285067   38.562517            9.0     16
# 8      9951           1    1.0   46.887892   44.628132            1.0     12
# 11    16755          88    2.0   53.975144   34.153584            8.0      2
# ...     ...         ...    ...         ...         ...            ...    ...
# 9993   9289           1    3.0   84.486078   88.931509            0.0      4
# 9995   1260          61    2.0   49.090728   33.272626            6.0      3
# 9996  16265          27    2.0   64.307684   37.038420            9.0     13
# 9997   2795         178    1.0   29.648057   16.555363            5.0      3
# 9999   7202          94    1.0   35.815476   22.301367            6.0      9
#
# ...
